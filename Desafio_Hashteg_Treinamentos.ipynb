# %% [markdown]
# ---
# ---
#
# # Código criado junto a equipe da (https://www.instagram.com/hashtagprogramacao/)
#
# # Durante o curso Gratuito de python oferecido pela Hasteg Treinamentos (https://pages.hashtagtreinamentos.com/minicurso-python-curso-basico-python-obrigado?blog=1n4033rer&video=2t0630j73)
#
# ---
# ---

# %% [markdown]
# # Conteúdo aprendido:
# ---
# ---
#
# #-Aplicações de Python, Instalação e Lógica de Programação
# #-Importar bibliotecas e exibir informações
# #-Estruturas de repetição e format
# #-Estruturas de condição e texto
# #-Tabelas e base de dados
# #-Indicadores graficos
# #-Indetação utilizando o "Tab";
# #-Estruturas de repetição "for";
# #-Concetar ao Google Drive usando o "os";
# #-Formatação para texto;

# %% [markdown]
# # 1. Lógica de programação
# ---

# %%
# Passo 0 - Entender o Desafio que você quer resolver

    # (Analisar as vendas da empresa)

# Passo 1 - Percorrer todos os arquivos da pasta base de dados (Pasta Vendas)

import os
import pandas as pd

lista_arquivo = os.listdir('/content/drive/MyDrive/Vendas')
display(lista_arquivo)
# Out:
# ['Devolucoes - Belo Horizonte.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Vendas - Goiás.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Vendas - Salvador.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Curitiba.csv',
#  'Vendas - Fortaleza.csv',
#  'Devolucoes - Salvador.csv',
#  'Devolucoes - São Paulo.csv',
#  'Vendas - Recife.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Devolucoes - Goiás.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Curitiba.csv']

# %%
# Passo 2 - Importar as bases de dados vendas

tabela_total = pd.DataFrame()

for arquivo in lista_arquivo:
  if 'Vendas' in arquivo:
   tabela = pd.read_csv(f"/content/drive/MyDrive/Vendas/{arquivo}")
   tabela_total = tabela_total.append(tabela)

# Passo 3 - Tratar\Compilar as baes de dados

   display(tabela_total)
# Out:
#      Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0            13  HL4379   Televisão                   1        Daniel
# 1            19  HL9962     Android                   4        Elaine
# 2            45  HL1918      iPhone                   5         Lenon
# 3            50  HL7348  SmartWatch                   1      Vivianne
# 4            97  HL7348  SmartWatch                   2         Pedro
# ..          ...     ...         ...                 ...           ...
# 727        9925  HL1918      iPhone                   2        Victor
# 728        9937  HL8851    Notebook                   2       Gabriel
# 729        9943  HL2714      Tablet                   2      Giuseppe
# 730        9968  HL2714      Tablet                   2          Caio
# 731        9975  HL8851    Notebook                   2          Anna
#
#      Sobrenome        Data   Loja  Preco Unitario  Unnamed: 8
# 0     Monteiro   5/23/2018  Goiás            2500         NaN
# ...

# %%
# Passo 4 - Calcular o produto mais vendido (em quantidade)
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida
# Produto
# iPhone                    8398
# Televisão                 5509
# Notebook                  3001
# Android                   2937
# SmartWatch                2809
# Tablet                    2707
# Câmera                    2579

# %%
# Passo 5 - Calcular o produto que mais  faturou (em faturamento)
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']
display(tabela_total)

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[['Faturamento']].sort_values(by='Faturamento', ascending=False)
display(tabela_faturamento)
# Out:
#      Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0            13  HL4379   Televisão                   1        Daniel
# 1            19  HL9962     Android                   4        Elaine
# 2            45  HL1918      iPhone                   5         Lenon
# 3            50  HL7348  SmartWatch                   1      Vivianne
# 4            97  HL7348  SmartWatch                   2         Pedro
# ..          ...     ...         ...                 ...           ...
# 714        9859  HL2714      Tablet                   1         Júlio
# 715        9876  HL4379   Televisão                   5         Bruno
# 716        9918  HL1148      Câmera                   2         Lucas
# 717        9944  HL1918      iPhone                   5       Raphael
# 718        9998  HL7348  SmartWatch                   1      Vinícius
#
#      Sobrenome        Data      Loja  Preco Unitario  Unnamed: 8  Faturamento
# ...

# %%
# Passo 6 - Calcular a loja\cidade que mais vendeu (em faturamento) - criar dashboard

tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabelas_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
import plotly.express as px

grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
